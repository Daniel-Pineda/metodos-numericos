# %%
import matplotlib.pyplot as plt

def fx(y):
	return 0.25+(0.25*y)

def fy(x, z):
	return 0.25+(0.25*x)+(0.25*z)

def fz(y, w):
	return 0.25+(0.25*y)+(0.25*w)

def fw(z):
	return 0.25+(0.25*z)

# DECLARACIÓN DE VARIABLES
listaX = []
listaY = []
listaZ = []
listaW = []
cont = 0

listaX.append(0)
listaY.append(0)
listaZ.append(0)
listaW.append(0)

while (cont < 20):
	listaX.append(fx(listaY[cont]))	
	listaY.append(fy(listaX[cont+1], listaZ[cont]))
	listaZ.append(fz(listaX[cont+1], listaW[cont]))
	listaW.append(fw(listaZ[cont+1]))
	cont+=1

for i in range(len(listaX)):	
	print("x"+str(i),"=", "{:^3.5f}, ".format(listaX[i]), end = " ")
	print("y"+str(i),"=", "{:^3.5f}, ".format(listaY[i]), end = " ")
	print("z"+str(i),"=", "{:^3.5f}, ".format(listaZ[i]), end = " ")
	print("w"+str(i),"=", "{:^3.5f}, ".format(listaW[i]), end = "\n")

plt.plot(listaX, label = "X")
plt.plot(listaY, label = "Y")
plt.plot(listaZ, label = "Z")
plt.plot(listaW, label = "W")
plt.legend()
plt.show()
# Out:
# x0 = 0.00000,  y0 = 0.00000,  z0 = 0.00000,  w0 = 0.00000,
# x1 = 0.25000,  y1 = 0.31250,  z1 = 0.31250,  w1 = 0.32812,
# x2 = 0.32812,  y2 = 0.41016,  z2 = 0.41406,  w2 = 0.35352,
# x3 = 0.35254,  y3 = 0.44165,  z3 = 0.42651,  w3 = 0.35663,
# x4 = 0.36041,  y4 = 0.44673,  z4 = 0.42926,  w4 = 0.35732,
# x5 = 0.36168,  y5 = 0.44774,  z5 = 0.42975,  w5 = 0.35744,
# x6 = 0.36193,  y6 = 0.44792,  z6 = 0.42984,  w6 = 0.35746,
# x7 = 0.36198,  y7 = 0.44796,  z7 = 0.42986,  w7 = 0.35747,
# x8 = 0.36199,  y8 = 0.44796,  z8 = 0.42986,  w8 = 0.35747,
# x9 = 0.36199,  y9 = 0.44796,  z9 = 0.42986,  w9 = 0.35747,
# x10 = 0.36199,  y10 = 0.44796,  z10 = 0.42986,  w10 = 0.35747,
# x11 = 0.36199,  y11 = 0.44796,  z11 = 0.42986,  w11 = 0.35747,
# x12 = 0.36199,  y12 = 0.44796,  z12 = 0.42986,  w12 = 0.35747,
# x13 = 0.36199,  y13 = 0.44796,  z13 = 0.42986,  w13 = 0.35747,
# x14 = 0.36199,  y14 = 0.44796,  z14 = 0.42986,  w14 = 0.35747,
# x15 = 0.36199,  y15 = 0.44796,  z15 = 0.42986,  w15 = 0.35747,
# x16 = 0.36199,  y16 = 0.44796,  z16 = 0.42986,  w16 = 0.35747,
# x17 = 0.36199,  y17 = 0.44796,  z17 = 0.42986,  w17 = 0.35747,
# x18 = 0.36199,  y18 = 0.44796,  z18 = 0.42986,  w18 = 0.35747,
# x19 = 0.36199,  y19 = 0.44796,  z19 = 0.42986,  w19 = 0.35747,
# x20 = 0.36199,  y20 = 0.44796,  z20 = 0.42986,  w20 = 0.35747,
