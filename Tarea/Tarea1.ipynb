# %%
import matplotlib.pyplot as plt 
import math

# ECUACIONES
def fx(y):
	return 0.25+(0.25*y)

def fy(x, z):
	return 0.25+(0.25*x)+(0.25*z)

def fz(y, w):
	return 0.25+(0.25*y)+(0.25*w)

def fw(z):
	return 0.25+(0.25*z)

# DECLARACIÓN DE VARIABLES
listaX = []
listaY = []
listaZ = []
listaW = []
cont = 0

listaX.append(0)
listaY.append(0)
listaZ.append(0)
listaW.append(0)

while (cont < 20):
	listaX.append(fx(listaY[cont]))	
	listaY.append(fy(listaX[cont], listaZ[cont]))
	listaZ.append(fz(listaY[cont], listaW[cont]))
	listaW.append(fw(listaZ[cont]))
	cont+=1

for i in range(len(listaX)):	
	print("x"+str(i),"=", "{:^3.5f}, ".format(listaX[i]), end = " ")
	print("y"+str(i),"=", "{:^3.5f}, ".format(listaY[i]), end = " ")
	print("z"+str(i),"=", "{:^3.5f}, ".format(listaZ[i]), end = " ")
	print("w"+str(i),"=", "{:^3.5f}, ".format(listaW[i]), end = "\n")

plt.plot(listaX, label = "X")
plt.plot(listaY, label = "Y")
plt.plot(listaZ, label = "Z")
plt.plot(listaW, label = "W")
plt.legend()
plt.show()
# Out:
# x0 = 0.00000,  y0 = 0.00000,  z0 = 0.00000,  w0 = 0.00000,
# x1 = 0.25000,  y1 = 0.25000,  z1 = 0.25000,  w1 = 0.25000,
# x2 = 0.31250,  y2 = 0.37500,  z2 = 0.37500,  w2 = 0.31250,
# x3 = 0.34375,  y3 = 0.42188,  z3 = 0.42188,  w3 = 0.34375,
# x4 = 0.35547,  y4 = 0.44141,  z4 = 0.44141,  w4 = 0.35547,
# x5 = 0.36035,  y5 = 0.44922,  z5 = 0.44922,  w5 = 0.36035,
# x6 = 0.36230,  y6 = 0.45239,  z6 = 0.45239,  w6 = 0.36230,
# x7 = 0.36310,  y7 = 0.45367,  z7 = 0.45367,  w7 = 0.36310,
# x8 = 0.36342,  y8 = 0.45419,  z8 = 0.45419,  w8 = 0.36342,
# x9 = 0.36355,  y9 = 0.45440,  z9 = 0.45440,  w9 = 0.36355,
# x10 = 0.36360,  y10 = 0.45449,  z10 = 0.45449,  w10 = 0.36360,
# x11 = 0.36362,  y11 = 0.45452,  z11 = 0.45452,  w11 = 0.36362,
# x12 = 0.36363,  y12 = 0.45454,  z12 = 0.45454,  w12 = 0.36363,
# x13 = 0.36363,  y13 = 0.45454,  z13 = 0.45454,  w13 = 0.36363,
# x14 = 0.36364,  y14 = 0.45454,  z14 = 0.45454,  w14 = 0.36364,
# x15 = 0.36364,  y15 = 0.45454,  z15 = 0.45454,  w15 = 0.36364,
# x16 = 0.36364,  y16 = 0.45455,  z16 = 0.45455,  w16 = 0.36364,
# x17 = 0.36364,  y17 = 0.45455,  z17 = 0.45455,  w17 = 0.36364,
# x18 = 0.36364,  y18 = 0.45455,  z18 = 0.45455,  w18 = 0.36364,
# x19 = 0.36364,  y19 = 0.45455,  z19 = 0.45455,  w19 = 0.36364,
# x20 = 0.36364,  y20 = 0.45455,  z20 = 0.45455,  w20 = 0.36364,
